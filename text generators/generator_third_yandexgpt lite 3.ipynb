# %%
import pandas as pd
import requests
import json

operations_ids = []


prev_titles = []
news_dataset = pd.read_csv('Lenta_dataset.csv')
news_dataset.head()
# Out:
#    Unnamed: 0                                           url  \
# 0           0  https://lenta.ru/news/2018/12/15/disneyland/
# 1           1       https://lenta.ru/news/2018/12/15/usa25/
# 2           2   https://lenta.ru/news/2018/12/15/integrity/
# 3           3       https://lenta.ru/news/2018/12/15/sobor/
# 4           4      https://lenta.ru/news/2018/12/15/skrepy/
#
#                                                title  \
# 0       Обнаружено самое счастливое место на планете
# 1  В США раскрыли сумму расходов на расследование...
# 2  Хакеры рассказали о планах Великобритании зами...
# 3  Архиепископ канонической УПЦ отказался прийти ...
# 4  Российскую молодежь предложили обучать духовны...
#
#                                                 text           topic  \
# 0  Сотрудники социальной сети Instagram проанализ...     Путешествия
# 1  С начала расследования российского вмешательст...             Мир
# 2  Хакерская группировка Anonymous опубликовала н...             Мир
# 3  Архиепископ канонической Украинской православн...     Бывший СССР
# 4  Российская молодежь лучше усвоит духовные ценн...  Интернет и СМИ
#
#        tags  date
# 0       Мир   NaN
# 1  Политика   NaN
# 2  Общество   NaN
# 3   Украина   NaN
# 4   Coцсети   NaN

# %%
news_dataset = news_dataset.drop(['Unnamed: 0'], axis=1)

# %%
news_dataset.to_csv('Lenta_dataset.csv')

# %%
news_dataset.tags.unique()
# Out:
# array(['Мир', 'Политика', 'Общество', 'Украина', 'Coцсети',
#        'Следствие и суд', 'Хоккей', 'Деньги', 'Госэкономика',
#        'Происшествия', 'Футбол', 'Зимние виды', 'Бизнес', 'Музыка',
#        'Квартира', 'Бокс и ММА', 'Театр', 'Оружие', 'Дача', 'Прибалтика',
#        'Рынки', 'Звери', 'Техника', 'Интернет', 'Люди', 'Наука',
#        'Внешний вид', 'Кино', 'ТВ и радио', 'Регионы', 'Космос',
#        'Явления', 'Стиль', 'Белоруссия', 'События', 'Деловой климат',
#        'Все', 'Искусство', 'Движение', 'Преступность', 'Криминал',
#        'Жизнь', 'Мнения', 'Полиция и спецслужбы', 'Конфликты', 'Авто',
#        'Книги', 'Вкусы', 'Фотография', 'Реклама', 'Закавказье', nan,
#        'Часы', 'Летние виды', 'Россия', 'Пресса', 'Вещи', 'История',
#        'Игры', 'Достижения', 'Офис', 'Средняя Азия', 'Еда', 'Москва',
#        'Социальная сфера', 'Молдавия', 'Преступная Россия', 'Гаджеты',
#        'Город', 'Киберпреступность', 'Страноведение', 'Софт',
#        'Инструменты', 'Вирусные ролики', 'Экология', 'Выборы', 'Мемы',
#        'Наследие', 'Туризм', 'Вооружение', 'Мировой бизнес', 'Автобизнес',
#        'Финансы компаний', 'Производители', 'Аналитика рынка',
#        'Госрегулирование', 'Мировой опыт', 'Инновации'], dtype=object)

# %%
already_have = pd.read_csv('dataset_generated_to_not.csv')
already_have_titles = already_have.title

# %%
safe_df = news_dataset[(news_dataset['tags'].isin(['Пресса', 'Вещи', 'История',
       'Игры', 'Достижения', 'Офис', 'Мемы',
       'Наследие', 'Туризм', 'Страноведение', 'Софт','Футбол', 'Зимние виды', 'Бизнес', 'Музыка',
       'Квартира', 'Бокс и ММА', 'Театр',
       'Инструменты', 'Вирусные ролики', 'Экология', 'Часы', 'Звери', 'Техника', 'Интернет', 'Люди', 'Наука',
       'Внешний вид', 'Кино', 'ТВ и радио', 'Летние виды', 'Средняя Азия', 'Еда', 'Авто',
       'Книги', 'Вкусы', 'Фотография', 'Реклама'])) & (~news_dataset.title.isin(already_have_titles))]
safe_df
# Out:
#         Unnamed: 0                                              url  \
# 26              26  https://lenta.ru/news/2018/12/15/protiv_russia/
# 27              27       https://lenta.ru/news/2018/12/15/poorkids/
# 31              31          https://lenta.ru/news/2018/12/15/mebel/
# 32              32       https://lenta.ru/news/2018/12/15/putinrap/
# 38              38            https://lenta.ru/news/2018/12/15/spb/
# ...            ...                                              ...
# 161258      161258           https://lenta.ru/news/2016/01/25/orgy/
# 161260      161260        https://lenta.ru/news/2016/01/25/reuters/
# 161261      161261        https://lenta.ru/news/2016/01/25/breguet/
# 161263      161263           https://lenta.ru/news/2016/01/25/dino/
# 161264      161264     https://lenta.ru/news/2016/01/25/belikebill/
#
#                                                     title  \
# 26      Биатлонистов Чехии, Канады и США заподозрили в...
# 27      Johnson&Johnson скрывала наличие канцерогена в...
# 31                 Моуринью сравнил футболистов с мебелью
# 32            Путин предостерег от запретов рэп-концертов
# 38               В Петербурге нашли квартиру из 58 комнат
# ...                                                   ...
# 161258  Семейные оргии с проститутками довели еврейску...
# 161260  Опубликован список самых влиятельных в мире уч...
# 161261  Мануфактура Breguet представила новые женские ...
# 161263  Житель США на спор вышел разгребать снег в кос...
# 161264   Мем «Будь как Билл» стал популярен в Афганистане
#
#                                                      text            topic  \
# 26      Комментатор Дмитрий Губерниев сообщил, что ино...            Спорт
# 27      Компания Johnson&Johnson, уличенная в использо...        Экономика
# 31      Главный тренер «Манчестер Юнайтед» Жозе Моурин...            Спорт
# 32      Президент России Владимир Путин, выступая на з...         Культура
# 38      В Московском районе Санкт-Петербурга на продаж...              Дом
# ...                                                   ...              ...
# 161258  Супружеская пара из Израиля обратилась в равви...         Из жизни
# 161260  Компания Thomson Reuters представила отчет «Са...  Наука и техника
# 161261  Швейцарская часовая мануфактура Breguet предст...         Ценности
# 161263  Житель американского штата Кентукки Клифф Уайт...         Из жизни
# 161264  В Афганистане появился свой аналог интернет-ме...   Интернет и СМИ
#
#                tags  date
# 26      Зимние виды   NaN
# 27           Бизнес   NaN
# 31           Футбол   NaN
# 32           Музыка   NaN
# 38         Квартира   NaN
# ...             ...   ...
# 161258         Люди   NaN
# 161260        Наука   NaN
# 161261         Часы   NaN
# 161263         Люди   NaN
# 161264     Интернет   NaN
#
# [44835 rows x 7 columns]

# %%
generated_result = pd.DataFrame(columns=['title', 'generated_text'])
generated_result.head()
# Out:
# Empty DataFrame
# Columns: [title, generated_text]
# Index: []

# %%
now_titles = safe_df.title.sample(500)
titles =  [x for x in now_titles if x not in prev_titles]
prev_titles = prev_titles + titles 
titles
# Out:
# ['Акинфеев пропустил в\xa042-м матче Лиги чемпионов подряд',
#  'Переделанный в\xa0джакузи автомобиль показали на\xa0видео',
#  'Ученые МГУ создали безвредные наночастицы для лечения рака',
#  'Китай посулил десятки тысяч долларов за\xa0доносы о\xa0порно',
#  '70-летний пенсионер в\xa0третий раз пересек Атлантический океан на\xa0байдарке',
#  'Рядом с\xa0Россией нашли загадочный источник радиоактивного заражения',
#  'Жене Караченцова пригрозили лишением водительских прав',
#  'Порнографию назвали одной из\xa0причин разводов',
#  'Боец UFC сделал девушке предложение на\xa0ринге после победы нокаутом',
#  'Задержанный на\xa0Украине российский журналист попросил защиты у\xa0Путина',
#  'На Украине запретили немецкий боевик из-за «доблестного майора ФСБ»',
#  'Игрок сборной России объяснил сборы в\xa0Австрии бегством от «искусов цивилизации»',
#  'Осужденный пожизненно игрок в\xa0американский футбол покончил с\xa0собой',
#  'Россиянин назвал депутата «гондоном» в\xa0сети и\xa0поплатился',
#  'В ФАС положительно отнеслись к\xa0объединению Uber и «Яндекс.Такси»',
#  'Моуринью признался в «сливе» матча в\xa0бытность тренером «Челси»',
#  'Warner Bros. включила собственный сайт в\xa0список пиратских ресурсов',
#  'Кобзона лишили звания почетного гражданина города Славянска Донецкой области',
#  'Трезвый одессит прогулялся босиком по\xa0крыше и\xa0примерз',
#  'Усадьбу кондитерских королей в\xa0Москве оценили в\xa0полмиллиарда рублей',
#  'Estee Lauder заставит кожу женщин сиять по\xa0ночам',
#  'Союз биатлонистов России признал выступление сборной неудовлетворительным',
#  'Житель Алтая украл шестилетнего ребенка у\xa0бывшей жены и\xa0перевозил в\xa0сумке',
#  'Черепаха обогнала зайца в\xa0прямом эфире Facebook',
#  'Житель США на\xa0спор вышел разгребать снег в\xa0костюме тираннозавра',
#  'Туристка случайно повторила мем «неверный парень» и\xa0прославилась',
#  'Названы любимые банки московских ипотечников',
#  'Защитник ЦСКА сравнил матчи в\xa0Лиге чемпионов с\xa0играми за\xa0сборную',
#  'Мэйуэзер пожелал провести бой с\xa0Макгрегором в\xa0Москве',
#  '32-летний аргентинец Тевес станет самым высокооплачиваемым футболистом мира',
#  '«Реал» объявил имя нового главного тренера',
#  'Путин подмигнул ньюйоркцам с\xa0экрана Таймс-сквер и\xa0исчез',
#  'Тодоровский и\xa0Ярмольник побоялись ехать в\xa0Одессу из-за черного списка',
#  'В деле об\xa0изнасиловании с\xa0участием Роналду появились новые подробности',
#  'Подвергавшаяся издевательствам из-за лишнего веса британка стала моделью',
#  'РЖД потратит на\xa0обновление подвижного состава 70\xa0миллиардов рублей',
#  '«Атлетико» стал первым полуфиналистом Лиги чемпионов',
#  'Самую дорогую рекламу в\xa0мире заменили черным экраном',
#  'Новый фильм Вуди Аллена откроет Каннский фестиваль',
#  'Мединский появился в\xa0ролике видеоблогера Саши Спилберг',
#  'Алмаз размером с\xa0теннисный мяч отказались покупать',
#  'Умер лауреат Нобелевской премии по\xa0физике Алексей Абрикосов',
#  'Литовский суд оставил в\xa0силе штраф «Газпрому» в\xa035,6\xa0миллиона евро',
#  'Самый титулованный футболист в\xa0истории нашелся во\xa0Франции',
#  'На рынке сверхдорогой недвижимости зафиксирован гендерный дисбаланс',
#  'Суровый барнаулец остановил машину взглядом',
#  'Шувалов рассказал о\xa0проблемах с\xa0жильем в\xa0России',
#  'Рэпер Янг Лин попросил отыскать своего двойника-солдата из\xa0России',
#  'В Южной Корее прошло соревнование по\xa0ничегонеделанию',
#  'Названы последствия использования электронных сигарет',
#  'Виталий Кличко оценил возможность реванша брата с\xa0Джошуа',
#  'Стас Костюшкин пообещал фанатам оплатить счета за\xa0электричество',
#  'Американскую журналистку уволили за\xa0оскорбительный твит о\xa0Трампе и\xa0его дочери',
#  'Часовщики Officine Panerai переосмыслили дизайн модели-бестселлера',
#  'Страховщики составили рейтинг самых заливающих соседей',
#  'Месси побоялся возвращаться на\xa0родину',
#  'Власти Москвы пригрозили застройщикам судом ',
#  'Напавший на\xa0российского велогонщика болельщик оказался сумасшедшим',
#  '«Ашан» начнет поставлять в\xa0Италию российские товары',
#  'В Санкт-Петербурге завершился пятый чемпионат по\xa0футболу для дружбы',
#  'СМИ назвали игрока китайского клуба самым высокооплачиваемым футболистом в\xa0мире',
#  'Журналистам из\xa0США помешали осветить прибытие Обамы в\xa0КНР',
#  'Человекоподобный робот научился делать сальто',
#  'Умер актер из\xa0сериала «Каменская»',
#  'Австралийский вор напился элитного шампанского и\xa0уснул во\xa0взломанном доме',
#  'Европейцев обвинили в\xa0заражении Азии и\xa0Африки дизентерией',
#  'Акул у\xa0берегов Великобритании станет больше',
#  "Россиянин Брутт признан самым активным гонщиком многодневки «Джиро д'Италия»",
#  'Американцы усомнились в\xa0здоровье своих детей',
#  'В ЮАР подросток выжил после укуса одной из\xa0самых ядовитых в\xa0мире змей',
#  'Актера «Бригады» избили в\xa0Москве',
#  'Китайцы захотели купить Роналду',
#  'В Санкт-Петербурге стали строить меньше жилья',
#  'Дом-мемориал Робину Уильямсу выставили на\xa0продажу в\xa0Сан-Франциско',
#  'Актриса из «Звездных войн» отказалась идти с\xa0фанатом на\xa0выпускной',
#  'Бывший главред Forbes станет генпродюсером канала РБК',
#  'Из Крыма ушла последняя западная сеть отелей',
#  '«Группа ВГС» выкупила бизнес ISNEXT',
#  'Армия снеговиков в\xa0Англии похоронила снежную бабу и\xa0потребовала правосудия',
#  'Аналитики проверили достоверность погодных примет',
#  'В Париже проукраинские активисты напали на\xa0журналистку RT',
#  'В летнем расписании «Аэрофлота» сделан акцент на\xa0развитии внутренних перевозок',
#  'Американка преобразила 97-летнюю прабабушку с\xa0помощью макияжа',
#  '55-летний житель Красноярска побил мировой рекорд по\xa0подтягиваниям',
#  'В Новой Зеландии полицейские задержали детеныша тюленя',
#  'Австралиец слетал в «Макдоналдс» на\xa0вертолете',
#  'Элтон Джон отверг обвинения телохранителя в\xa0сексуальных домогательствах',
#  'В квартире бывшего сотрудника зоопарка нашли кобру и\xa0еще 16\xa0опасных рептилий',
#  '«Крымской Атлантиде» предрекли тотальное уничтожение',
#  'Форвард сборной Чили Санчес признан лучшим игроком Кубка Америки',
#  '«Нордавиа» заявила о\xa0попытке рейдерского захвата компании',
#  'Дайвер ввел тигровую акулу в\xa0транс',
#  'Фуркад выступил против коллективной ответственности за\xa0допинг',
#  'Представлена будущая судоходная карта Северного Ледовитого океана',
#  'Вышел новый промо-ролик фильма «Лего» про Бэтмена',
#  'В Петербурге в\xa02015\xa0году гостиничные операторы не\xa0открыли новые отели',
#  'Россиянин разбил в\xa0съемной квартире наркоплантацию',
#  'В Салехарде открылся инновационный детский сад',
#  'Новый роман Харуки Мураками выйдет в\xa0феврале',
#  'Модель поплавала с\xa0усатой акулой-нянькой и\xa0чуть не\xa0лишилась руки',
#  'Найден способ предсказать смерть',
#  'Самый ненавистный человек в\xa0США заинтересовался крупнейшим источником мемов',
#  'Роналду разорвет все связи с\xa0Испанией',
#  'Трамп огорчил 89-летнего диктора отказом от\xa0его услуг во\xa0время инаугурации',
#  'Президент Киргизии похвалил женщин за\xa0мужество',
#  'Бывший футболист «Зенита» похвастался частным самолетом',
#  'Бывший футболист сборной Буркина-Фасо умер во\xa0время матча',
#  'В Европе начал пробуждаться вызвавший вымирание неандертальцев супервулкан',
#  'Бывшая подруга Мела Гибсона останется без 500\xa0тысяч долларов из-за интервью',
#  'Опубликована крупнейшая коллекция оккультных книг',
#  'Мужчина сбросил полцентнера ради зачатия ребенка',
#  'Google спутал детские коляски для евреев с\xa0грилями на\xa0колесиках',
#  'Путин открыл в\xa0Кремле крест в\xa0память о\xa0князе Сергее Александровиче',
#  'Обвал спроса на\xa0съемные квартиры заметили в\xa0Москве',
#  'Назван самый симметричный член королевской семьи',
#  'Уилл Смит приехал в\xa0Россию, подружился с\xa0россиянами и\xa0заговорил по-русски',
#  'Иран обошел Россию в\xa0рейтинге ФИФА',
#  'Ассанж сообщил о\xa0захвате 700\xa0тысяч заполненных бюллетеней в\xa0Каталонии',
#  'Игроки «Локомотива» проведут футбольные уроки в\xa0московских школах',
#  'Эксперты предупредили пользователей о\xa0нашествии кибермутантов',
#  'Rado выпустили измеряющие скорость часы к\xa0Кубку Кремля',
#  'Переводчик Google уличили в\xa0сексизме',
#  'Актеры «Иронии судьбы» оценили перенос фильма с\xa0Первого канала на «Россию 1»',
#  'Большая белая акула увязалась за\xa0лодкой с\xa0семейной парой',
#  'Рассказ официанта-«террориста» о\xa0неблагодарных посетителях оказался обманом',
#  'Прыжок аллигатора в\xa0лодку с\xa0туристами попал на\xa0видео',
#  'Ученые впервые телепортировали энергию Солнца',
#  'Китайцы рассказали о\xa0работе на\xa0Apple до\xa0потери крови',
#  'Найдена зависимость между внешней привлекательностью и\xa0успехами биатлонистов',
#  'Последствия попадания ртути в\xa0унитаз показали на\xa0видео',
#  'Дочь Кафельникова из\xa0Лондона призналась в\xa0ненависти к\xa0России',
#  'Samsonite показал коллекцию бизнес-портфелей',
#  'Японская марка воссоздала часы Стива Джобса',
#  'Умер французский писатель Мишель Бютор',
#  'Олимпийский чемпион Тищенко вышел в\xa0финал ЧЕ\xa0по боксу',
#  'Полицейский сломал ногу болельщику «Зенита»',
#  'Джамала пожелала выступать в\xa0Крыму',
#  'Иван Ургант высмеял решение властей Екатеринбурга закатать в\xa0асфальт старый пень',
#  'Телеведущий поведал об\xa0изнурительной борьбе с\xa0раком',
#  'Роналду увидел в\xa0себе заслуженно лучшего футболиста мира',
#  'Путин на «Циклоне Б» и\xa0намек на\xa0Третий рейх попали на\xa0польские плакаты',
#  'Грузинский биолог объяснил природу гомосексуальности',
#  '«Эксмо» взяло на\xa0себя ответственность за «плагиат» в\xa0книге Маркина',
#  '«Игру престолов» превратили в\xa0аниме',
#  'СМИ узнали о\xa0планируемой экспансии Peugeot-Citroёn в\xa0Иран',
#  'Китаец собрал миниатюру древнего храма из\xa015\xa0тысяч палочек для еды',
#  'Фильм Кончаловского «Рай» вошел в\xa0шорт-лист премии «Оскар»',
#  'Шесть россиян завоевали золотые медали во\xa0второй день ЧЕ\xa0по самбо в\xa0Минске',
#  'Огромную стаю акул-молотов сняли на\xa0видео',
#  'В полиции рассказали о\xa0стычках между фанатами «Спартака» и\xa0ЦСКА в\xa0метро',
#  'Найден способ вылечить рак в\xa0последней стадии',
#  'Представлен масштабный трейлер Mass Effect: Andromeda',
#  'Спасающиеся от\xa0наводнения крысы заполонили Париж',
#  'Показана Assassin’s Creed в\xa0Древнем Египте',
#  'Шнуров намекнул на\xa0коллаборацию с\xa0Pharaoh',
#  'Существование интернет-порно поразило Тома Круза',
#  'Австралийка создала бизнес на\xa0продаже пончиков без сахара',
#  'Земфира рассказала об\xa0отношениях с\xa0Ренатой Литвиновой',
#  'В РЖД рассказали о\xa0судьбе плацкартных вагонов',
#  'В австралийском зоопарке тигр подружился с\xa0немецкой овчаркой',
#  'В Перу отказались принимать законопроект ради участия в\xa0ЧМ в\xa0России',
#  'Компания Вайнштейна обанкротилась',
#  'Рассказ британки о\xa0жизни с\xa0четырьмя мужчинами шокировал телезрителей',
#  'Ургант обсмеял Кашпировского после жалобы в\xa0суд на\xa0коллаж с\xa0котом',
#  'Неухоженность Ким Кардашьян возмутила поклонников',
#  'Уволенного за\xa0провал «Монако» тренера сосватали в «Реал»',
#  'Тимакова подтвердила подлинность найденного Медведевым в\xa0сети RuTracker',
#  'СМИ рассказали о\xa0желании Усманова купить 67-процентную долю «Арсенала»',
#  'Черчесов рассказал о\xa0насытившемся русской кровью допинг-офицере',
#  'Ведущий BBC отрезал себе фрагмент мышцы ради вкуса человечины ',
#  'Индиец с\xa0ампутированными руками стал звездой крикета ',
#  'Поведение маленькой девочки в\xa0эфире телешоу шокировало зрителей',
#  'В Бангладеш летевший на\xa0свадьбу вертолет по\xa0ошибке приземлился в\xa0тюрьме',
#  'Биткоин отвоевал отметку 10\xa0тысяч долларов и\xa0упал обратно',
#  'Королевскую змею нашли в\xa0подъезде дома на\xa0востоке Москвы',
#  'Officine Panerai снабдила часы Luminor Marina 1950\xa0металлическим браслетом',
#  'Удвоение «молекулы жизни» впервые сняли на\xa0видео',
#  '114-летняя китаянка вышла замуж за\xa071-летнего соседа по\xa0дому престарелых',
#  'Из Пекина выселят два миллиона человек',
#  'Пес присел отдохнуть за\xa0руль газонокосилки после торнадо в\xa0Техасе',
#  'Роль апостола Петра предложили чернокожему актеру',
#  'Аршавин забил мяч в\xa0полуфинале Кубка Казахстана',
#  'Бывший муж Бузовой оказался под угрозой уголовного дела',
#  'Во Франции оценили перспективы Головина',
#  'Халк забил ударом с\xa030\xa0метров',
#  'Академия Михалкова и\xa0Фонд Тимченко объявили о\xa0начале сотрудничества',
#  'Каждый десятый житель России оказался арендатором',
#  'Конгресс США лишил аккредитации журналистов RT',
#  'Вооруженный грабитель отобрал у\xa0игрока «Атлетико» часы за\xa070\xa0тысяч евро',
#  'Вакуум увеличил КПД солнечных батарей',
#  'Досрочные президентские выборы начались в\xa0Узбекистане',
#  'Михалков рассказал про обвинения в\xa0гомосексуализме и\xa0нашел в\xa0них выгоду',
#  'От лейкемии умер старший брат Эдди Мерфи и\xa0сценарист его фильмов Чарли',
#  'Женщина спрятала змею в\xa0жестком диске',
#  'Футболиста «Динамо» избили в\xa0Москве',
#  'Строительством «Зенит-Арены» займется штаб Полтавченко',
#  'Chanel предложила для аукциона Only Watch уникальные часы',
#  'Министр юстиции Польши потребует выдать Полански США',
#  'Названы предполагаемые убийцы журналиста Бабченко',
#  '90-летнего американца обвинили в\xa0сексуальных домогательствах',
#  'Спрос на\xa0съемные квартиры в\xa0Москве достиг пятилетнего максимума',
#  'Режиссер Меньшов пожалел об\xa0огласке передачи денег для Донбасса',
#  'Райан Гослинг «стал лицом» неизвестной криптовалюты',
#  'Фелпс бросил вызов Макгрегору',
#  'Преступница попросила заменить свое неудачное фото в\xa0объявлении о\xa0розыске',
#  'Найден мертвым 18-летний саксофонист-виртуоз Матвей Шерлинг',
#  'Хаски частично оправдали',
#  'Мультфильм «Маша и\xa0Медведь» обогнал Адель на\xa0YouTube',
#  'Киевский пластический хирург оспорил авторство фото пациентки с\xa0голой грудью',
#  '«Яндекс.Такси» и\xa0Gett проверят на\xa0ценовой сговор',
#  'В Туле преступник запер женщину в\xa0шкафу и\xa0ограбил квартиру',
#  'В Иркутской области построят школу за\xa0миллиард рублей',
#  '«Нафтогаз» увеличит размер иска к «Газпрому» на\xa0пять миллиардов долларов',
#  'На джазовом фестивале во\xa0Львове Митя Фомин назвал Крым российской территорией',
#  'Соцсеть начала блокировать профили за «педрильство» и «еврейство»',
#  'Действие материнского проклятия проследили на\xa0незрячих',
#  'Райан Рейнольдс пожелал любовника в\xa0продолжении «Дэдпула»',
#  'Samsung изобрела картонную коробку',
#  'Россияне обеспечили рост спроса на\xa0дорогое съемное жилье в\xa0Москве',
#  'В сети показали трагичную историю любви Ждуна и\xa0человека Грэма',
#  'Названа стоимость аренды квартир в\xa0Крыму на\xa0Новый год',
#  'Турецкий поэт извинился перед Россией в\xa0стихах',
#  'Художник изобразил карликового Трампа в\xa0болоте среди гадюк и\xa0жаб и\xa0объяснился',
#  'Эд Ширан появится в «Симпсонах»',
#  'Организаторы «Евровидения» отказались пересматривать итоги конкурса',
#  'Заполярные ученые научились превращать радиоактивные отходы в\xa0керамику',
#  'Муж Шурыгиной приготовился бить людей',
#  'Forbes назвал самых высокооплачиваемых музыкантов 2016\xa0года',
#  'Хакер залил гей-порно на\xa0страницы сотен сторонников «Исламского государства»',
#  'Ургант и\xa0Витя АК-47\xa0предложили «похватать на\xa0ротан» в\xa0стиле «Азино три топора»',
#  'Британский Красный Крест собрал более трех миллионов долларов на\xa0концерте Гранде',
#  'Приехавших в\xa0Молдавию российских артистов пообещали депортировать',
#  'Из-за высоких налогов с\xa0продаж мегадома Лондона потеряли в\xa0стоимости',
#  'Сборная России вышла в\xa0финал чемпионата мира по\xa0хоккею с\xa0мячом',
#  'Ямальский спортсмен привез домой золото мирового чемпионата',
#  'Актриса Даниэль Дарье умерла в\xa0возрасте 100\xa0лет',
#  'Британские хирурги впервые спасли новорожденную девочку с\xa0сердцем вне тела',
#  'Любовь Аксенова повыла и\xa0повалялась у\xa0Урганта',
#  'Кутузовский проспект подешевел',
#  'Прибыль ФСК ЕЭС превысила 72\xa0миллиарда рублей',
#  'Женщина впервые командовала сменой караула у\xa0Букингемского дворца',
#  'Роулинг объяснила упоминание Дамблдора в\xa0трейлере «Фантастических зверей»',
#  'Названа главная опасность онлайн-знакомств',
#  'Суд отказался закрыть дело о\xa0причастности Джима Керри к\xa0самоубийству подруги',
#  'ЦСКА отказался продлевать контракт с\xa0дисквалифицированным за\xa0кокаин Еременко',
#  'Ведущие телеканалы США отказались транслировать посвященный Трампу ролик',
#  'Определено оптимальное время для загара',
#  'Саратовца осудили на\xa0полтора года за\xa0взлом Xbox 360',
#  'Режиссер рассказал о\xa0реакции русских на «Смерть Сталина»',
#  'Конвульсии живого моллюска на\xa0суши попали на\xa0видео',
#  'На Airbnb предложили самый маленький дом в\xa0мире',
#  'Леди Гага обсудила психические отклонения с\xa0принцем Уильямом',
#  'Раскрыт секрет идеальной послеродовой фигуры',
#  'Данные 11\xa0миллионов человек оказались в\xa0открытом доступе',
#  '«Мордовия» предложила болельщикам обменять пачку сигарет на\xa0билет на\xa0матч',
#  'Боец АТО опубликовал видео с\xa0плевками в\xa0ведущего Шейнина',
#  'Enjoykin «заставил» Сергея Дружко объявить интернет-мобилизацию',
#  'Оправдание россиян разочаровало Родченкова',
#  'В Таджикистане обнаружили тысячи граждан республики в\xa0рядах ИГ',
#  'Журналисты «присвоили» ветерану чужой орден',
#  'Ученый рассказал о\xa0перспективах производства российского пармезана',
#  'Комик жестко высмеяла Иванку Трамп и\xa0назвала ее\xa0вагинальной петлей',
#  'Малахов назначен на\xa0пост главного редактора RNS',
#  'Трансляция #Основной выпускной набрала миллион просмотров во «ВКонтакте»',
#  'Россиянка убила соседку по\xa0подъезду из-за чересчур громкой музыки',
#  'Оксимирон и «Би-2» выпустили совместный трек',
#  'Названы самые высокооплачиваемые модели мира',
#  'Определился следующий соперник бойца ММА Харитонова',
#  'Ченнинг Татум расстался с\xa0женой',
#  'Навка удивилась реакции СМИ на\xa0выступление в\xa0образе узника Освенцима',
#  'В сети взбесились из-за рекламы с\xa0переодеванием черной женщины в\xa0белую',
#  'Bugaboo предложил молодым родителям коляски по\xa0французской моде',
#  'Сериал по «Властелину колец» станет самым дорогим в\xa0истории',
#  'Определена средняя максимальная продолжительность жизни человека',
#  'Участник «Евровидения» от\xa0Украины объяснил отказ от\xa0родного языка',
#  'Американец поставил рекорд по\xa0времени пребывания в\xa0виртуальной реальности',
#  'Газета опубликовала интервью с\xa0телезвездой без купюр и\xa0завоевала всеобщую любовь',
#  'Объяснена неспособность толстых людей нарастить мышцы',
#  'France Football поменял правила вручения «Золотого мяча»',
#  'Школьников Узбекистана оставили без выпускных вечеров',
#  'Российский биатлонист Логинов выиграл индивидуальную гонку на\xa0ЧЕ в\xa0Польше',
#  'Определились все участники группового этапа Лиги чемпионов',
#  'Жители Мурманска помогли вернуть всех сбежавших из\xa0приюта собак',
#  'Квят сошел с\xa0дистанции гонки Гран-при Китая',
#  'Благотворительный магазин попросил больше не\xa0сдавать ему книги «Код да\xa0Винчи»',
#  'Добрые люди собрали деньги для обворованной старушки',
#  'Трансгендер родил ребенка нейтрального пола',
#  'Огромная морковь огородника из\xa0США попала в\xa0Книгу рекордов Гиннесса',
#  'Оззи Осборн выступит в\xa0Москве',
#  'Швейцарские часовщики вспомнили 1960-е годы',
#  'Медведев подписал стратегию развития ЖКХ до\xa02020\xa0года',
#  'Американцы стали запасаться оружием для самообороны',
#  'Тарантино распекли за «шлюх» в\xa0приглашении на\xa0кастинг',
#  'Тарасова отчитала футболистов за\xa0неумение трудиться',
#  'Daily Mail раскритиковали за\xa0твит о «стильном костюме» убийцы российского посла',
#  'Умер писатель Фазиль Искандер',
#  'Автор книги «Когда умрут газеты» разглядел мистику в\xa0закрытии печатных изданий',
#  'Анна Нетребко выложила фото в\xa0купальнике',
#  'Считавшуюся утерянной запись Пола Маккартни выставили на\xa0аукцион',
#  'Исчезающий из\xa0банкоматов вирус вычислили по\xa0оставленным хакерами ругательствам',
#  'Мэрил Стрип публично затравили из-за секс-скандала',
#  'Футболист сборной Нидерландов потерял память во\xa0время матча с\xa0Бельгией',
#  'Украина уведомила «Газпром» об\xa0аресте акций «Газтранзита»',
#  'Российский лыжник одержал победу в\xa0Кубке мира',
#  'Объявлена дата премьеры балета Серебренникова «Нуреев»',
#  'Сотрудницу Google изнасиловали и\xa0убили во\xa0время пробежки',
#  'Интенсивное занятие спортом оказалось бесполезным для похудения',
#  'Поветкин победил украинца Руденко',
#  'Goodyear презентовала сферические покрышки',
#  'Фанаты начали резать себя в\xa0знак солидарности с\xa0Бейонсе',
#  'Раскрыта тайна Бермудского треугольника',
#  'На Украине вступил в\xa0силу механизм изъятия российских книг',
#  'Монголы пожаловались на\xa0гонения в\xa0Бурятии',
#  'Виктор Ан\xa0обратился к\xa0болельщикам',
#  'Британских паралимпийцев уличили в\xa0преднамеренном укорачивании конечностей',
#  'Мошенник собирал дань с\xa0министров в\xa0благодарность за\xa0должности и\xa0попался',
#  'В сети посмеялись над единственным зрителем фильма «Крым»',
#  'Опубликован список самых влиятельных в\xa0мире ученых',
#  'Испанский «Бетис» выгнал обвиненного в\xa0нацизме украинского футболиста',
#  'Раскрыты личности семи шпионов британской контрразведки',
#  'Уличенная в\xa0порнопрошлом учительница уволилась из\xa0петербургской гимназии',
#  'Меган Маркл припомнили президентские амбиции',
#  'Телефон Lamborghini из «жидкого металла» оценили в\xa02,5\xa0тысячи долларов',
#  'Самолет на\xa0солнечных батареях возобновил полет',
#  'В Мурманской области для космонавтов воссоздадут лунную поверхность',
#  'Хакер нашел возможность бесплатно ездить по\xa0карте «Тройка»',
#  'Пользователи PornHub обсудили Иисуса, политику и «киноляпы»',
#  'Уставшие от «лживых СМИ» британцы начали массово сжигать газеты',
#  'Журналисты потребовали запретить Кадырову въезд в\xa0Москву «ради спокойствия»',
#  'Футболист сборной России заявил о\xa0желании поскорее забыть чемпионат Европы',
#  'Раньери поблагодарил Хиддинка за\xa0чемпионство «Лестера»',
#  'Немецкие СМИ назвали финал Олимпиады с\xa0Россией «самым крутым поражением»',
#  'Ученые объяснили превращение безвредной бактерии в\xa0смертельно опасную',
#  'Сборная России по\xa0футболу сыграла вничью с\xa0командой Чили',
#  'Французский шеф-повар пожаловалась на\xa0вкусы приехавших в\xa0Канны американцев',
#  'Любящая обниматься с\xa0работниками зоопарка коала покорила соцсети',
#  'Эмир Кустурица откроет фестиваль русской музыки «Большой»',
#  'Московские коммунальщики полили улицы во\xa0время грозы',
#  'ФИФА назвала тройку претендентов на\xa0звание лучшего футболиста года',
#  'Найден способ получить «кусок» нейтронной звезды',
#  'СМИ сообщили  об\xa0исчезновении Оззи Осборна после ссоры с\xa0женой',
#  'В петербургской квартире нашли замурованный скелет',
#  'ФИФА оштрафовала Россию за\xa0дискриминационный баннер на\xa0матче с\xa0Уругваем',
#  'Командир российских наемников в\xa0Сирии занялся ресторанным делом',
#  'Бой в\xa0России лишит Нурмагомедова миллионов',
#  'Сотни «эйнштейнов» собрались в\xa0Торонто ради мирового рекорда',
#  'Слепой не\xa0смог изучить сайт Playboy и\xa0обозлился на\xa0него',
#  'Певица Штурм обвинила Осина в\xa0обмане с\xa0отнявшимися ногами ради алкоголя',
#  'Блогеры притворились кораблями и\xa0устроили масштабный морской бой',
#  'Экипаж «КамАЗ-Мастер» помог перевернувшемуся на «Шелковом пути» гонщику',
#  'Бьорндален прокомментировал пропуск Олимпиады-2018',
#  'Аргентинский футболист прыгнул на\xa0соперника двумя ногами',
#  'Ибрагимович выиграл суд у\xa0обвинившего его в\xa0применении допинга тренера',
#  'В Москве простились с\xa0Вячеславом Шалевичем',
#  'Джей и\xa0Молчаливый Боб вернутся',
#  'Макгрегор пообещал шокировать мир в\xa0бою с\xa0Мэйуэзером',
#  'О блокадном Ленинграде решили снять черную комедию',
#  'В IBU назвали сроки объявления замены этапу Кубка мира по\xa0биатлону в\xa0Тюмени',
#  'Парень устроил проверку хранилищу с\xa0помощью почти двух миллионов гигабайт порно',
#  'Названы самые плотно застроенные города Подмосковья',
#  'В сети обратили внимание на\xa0оптические иллюзии от\xa0корейской визажистки',
#  'Новейший российский БТР нырнул под воду и\xa0всплыл',
#  'Стала известна дата глобального сбоя интернета',
#  'Гамова нашла виноватых в\xa0награждении российских футболистов',
#  'Житель Москвы выставил на\xa0продажу полотенце Месси за\xa01,5\xa0миллиона рублей',
#  'Названы способствующие похудению крупы',
#  'Раскрыта личность подозреваемого в\xa0убийстве болгарской журналистки',
#  'Группа Slayer объявила о\xa0распаде',
#  'Названа самая уродливая собака в\xa0мире',
#  'Малышка на\xa0велосипеде поблагодарила водителя грузовика жестом и\xa0стала звездой',
#  'Группа Little Big представит новый альбом в\xa0Москве',
#  'Создатели «Ликвидации» опровергли сообщения о\xa0попытке Машкова въехать в\xa0Одессу',
#  '«Металлург» сравнял счет в\xa0финальной серии Кубка Гагарина',
#  'Дебютант РФПЛ отправил в\xa0ФИФА поддельный документ из-за нежелания платить долг',
#  'Поцелуй Кэти Перри с\xa019-летним музыкантом сочли сексуальным домогательством',
#  'Английский клуб захотел купить Смолова',
#  'В детской онлайн-игре обнаружили рассадник педофилов',
#  'В трейлере новых «Звездных войн» показали Дарта Вейдера',
#  'Васе Обломову запретили выступать в\xa0Москве в\xa0День России',
#  'Материнская компания Google установила рекорд по\xa0падению прибыли',
#  'Польские и\xa0ирландские фанаты подрались с\xa0жителями Ниццы',
#  'Сперме нашли неожиданное применение в\xa0женском здоровье',
#  'Вратарь «Лестера» пытался спасти владельца команды из\xa0горящего вертолета',
#  'Фанаты «Игры престолов» нашли способ предсказывать смерть персонажей',
#  'Бывший тренер «Зенита» возглавил клуб Халка',
#  'Канадcкий пенсионер второй раз выиграл миллион долларов в\xa0лотерею',
#  'Чемпион UFC уверовал в\xa0непобедимость Нурмагомедова',
#  'Черчесов оказался среди самых высокооплачиваемых тренеров на\xa0чемпионате мира',
#  'После смерти Джорджа Майкла в\xa0сети призвали защитить старейшего телеведущего',
#  'Российские и\xa0иностранные журналисты попали под артобстрел в\xa0Сирии',
#  'Футболисты сборной России подорожали после ЧМ-2018',
#  'Цены на\xa0одежду вырастут из-за обвала рубля',
#  'Продажи элитных брокеров Москвы уменьшились на\xa0миллиард',
#  'Москва в\xa0три раза обошла регионы по\xa0возможностям для шопинга',
#  'Найден способ заснуть вовремя',
#  'Живая улитка поселилась в\xa0гноящемся локте мальчика',
#  'РПЦ расскажет глухим о\xa0православии через YouTube-канал',
#  'Вышел трейлер нового «Кикбоксера» с\xa0Ван Даммом',
#  'Объяснено происхождение современного сифилиса',
#  'Гомер Симпсон поохотится на\xa0покемонов в\xa0зоопарке',
#  'У Нурмагомедова родился сын',
#  'Соперник Емельяненко в\xa0борьбе за\xa0чемпионский титул оказался его фанатом',
#  'Обнаружен способ победить невосприимчивый к\xa0лечению рак',
#  'Coca-Cola отказалась от\xa0слишком сладкой Coca-Cola',
#  'Умерла актриса Людмила Иванова',
#  '«Реал» и\xa0Бавария сыграют в\xa0форме из\xa0переработанного океанского мусора',
#  'На Роскомнадзор подали первый иск из-за блокировки Telegram',
#  '«Зенит» назначил Фурсенко гендиректором вместо Митрофанова',
#  'Пользователи сети перессорились из-за розового глобуса «для девочек»',
#  'Выдача ипотеки выросла на\xa080\xa0процентов',
#  'Дэвид Линч и\xa0его муза выпустили клип',
#  'Президент УЕФА посчитал «Ниву» пародией на\xa0автомобиль',
#  'Сюжет седьмого сезона «Игры престолов» слили в\xa0интернет полностью',
#  'Университетский клерк потратил тысячу часов на\xa0порно и\xa0поплатился',
#  'Лукашенко расстроили результаты сборной России по\xa0футболу',
#  'Госкомпании обязали закупать инновационные технологии у\xa0малого бизнеса',
#  'Первый канал объяснил выбор Самойловой для участия в «Евровидении»',
#  'Фанат сборной Хорватии принял участие в\xa0праздновании гола в\xa0ворота турок',
#  'Шнуров пообещал спеть пять песен про «Зенит» на\xa0стадионе «Спартака»',
#  'Гигантский iPod построят в\xa0Дубае',
#  'Французские ювелиры посвятили Ди\xa0Каприо телефон',
#  'Фигуристка Медведева вновь побила собственный мировой рекорд',
#  'Группа Linkin Park обвинила демонов в\xa0гибели Честера Беннингтона',
#  'Первый канал телепортировал собор из\xa0Саранска в\xa0Москву',
#  'Президент Эстонии выступит в\xa0качестве диджея в\xa0финском клубе',
#  'Любители порно со\xa0знаменитостями испугались кары за\xa0детскую эротику',
#  'Боец UFC назвал мешками всех соперников Емельяненко после 2005\xa0года',
#  'Сталлоне обвинили в\xa0надругательстве над 16-летней поклонницей',
#  'Боксер спас семерых после смерти',
#  'Армянский новичок «Манчестер Юнайтед» побил рекорд постсоветского пространства',
#  'Российские фанаты сняли драку с\xa0англичанами в\xa0Марселе на\xa0GoPro',
#  'Президент Таджикистана посоветовал гражданам запастись едой и\xa0водой',
#  'Самбурская отказалась «играть студентку до\xa0седых мудей» в «Универе»',
#  'Мутко прокомментировал решение Международного союза биатлонистов',
#  'США признали пропавшего саудовского журналиста мертвым',
#  'Леди Гага дебютирует в\xa0кино в\xa0фильме Брэдли Купера',
#  'Британка поблагодарила орангутана за\xa0ребенка после шести выкидышей',
#  '«Спартак» объяснил увольнение Карреры',
#  'Роналду попал в\xa0состав сборной Португалии на\xa0Кубок конфедераций-2017',
#  'Кокорин стал спонсором чемпионата Детской футбольной лиги',
#  'Домашнее задание британской учительницы сделало ее\xa0звездой интернета',
#  'Катя Лель раскрыла истинное значение «муа-муа» и «джага-джага»',
#  'Киселев объяснил фотографии в\xa0вышиванке и\xa0дружбу с\xa0Порошенко',
#  'Хэмилтон стал первым в\xa0квалификации Гран-при Мексики',
#  'Голландский архитектор предложил строить «бесконечные» дома',
#  'Журналисты назвали самого популярного спортсмена мира',
#  'Мировой эталон килограмма заменили',
#  'Концерт Агутина и\xa0Варум сорвали сообщением о\xa0минировании',
#  'Американец пошел по\xa0грибы и\xa0нашел двухголового олененка',
#  'Болт не\xa0получил миллионы и\xa0остался без клуба',
#  'WP узнала о\xa0планах Трампа снизить налог на\xa0прибыль предприятий до\xa015\xa0процентов',
#  'ООН призвала Душанбе разрешить таджикским женщинам выходить замуж за\xa0иностранцев',
#  'Мать-одиночка построила дом с\xa0помощью обучающих видео на\xa0YouTube',
#  'ЦБ пригласил краудфандинговые сайты на\xa0мониторинг',
#  'Савику Шустеру запретили работать на\xa0Украине',
#  'Американская певица создала поддерживающую грудь гитару',
#  'Британские инженеры предложили сушить волосы «сверхзвуковым» феном',
#  'Родченкова сочли недостойным зваться русским',
#  'Эдвард Сноуден назвал взлом серверов АНБ «приветом из\xa0России»',
#  'Украина продлит контракт с\xa0Россией по\xa0обогащению урана',
#  'Ученые выявили ген «материнского проклятия»',
#  'Определился следующий соперник Ковалева',
#  'Объяснены глубинные причины алкоголизма',
#  'Китай испытал гигантский самолет-амфибию',
#  'Колоду карт раздавили с\xa0помощью пресса',
#  'В правительстве опровергли информацию о\xa0прекращении финансирования WADA',
#  'Google заменит Android на\xa0более совершенную операционную систему',
#  'Россиянин извинился перед чернокожими за «расистский» фильтр',
#  'BMW начнет продавать доступные велосипеды',
#  'Названы самые смешные сюжеты в\xa0порно',
#  'Аргентинские болельщики запутались в\xa0Новгородах',
#  'Принц Гарри похвалил макияж Меган Маркл',
#  'Власти Москвы изъяли участок съемочной площадки «Дома-2»',
#  '«Зенит» обыграл «Арсенал» в\xa0матче РФПЛ',
#  'Производитель игрушек решил зарегистрировать товарный знак «Вежливые дети»',
#  '«Нашествие» в\xa02018\xa0году перенесут на\xa0август',
#  'Одноклубника Нурмагомедова нокаутировали в\xa0дебютном бою в\xa0UFC',
#  'Китаянка захотела вина со\xa0змеиным ядом и\xa0впала в\xa0кому',
#  'Журналист «Ленты.ру» назван лучшим молодым кинокритиком года',
#  'Обновление Windows 10\xa0убило устройства пользователей',
#  'Странный зверь с\xa0калифорнийской помойки оказался облысевшим медвежонком']

# %%
token = 'IAM-token'

# %%
def generate_text(title):
    url = "https://llm.api.cloud.yandex.net/foundationModels/v1/completionAsync"
    headers = {
           "Authorization": f"Bearer {token}",
           "Content-Type": "application/json"
       }
    data = {
  "modelUri": "gpt://b1gl2mq1047r4bitl8nj/yandexgpt-lite/rc",
  "completionOptions": {
    "stream": True,
    "temperature": 0.4,
    "maxTokens": 1000
  },
  "messages": [
    {
      "role": "system",
      "text": "Ты журналист новостного портала. Тебе необходимо написать статью на заданную тему."
    },
    {
      "role": "user",
      "text": f"Напиши новостную статью с заголовком: {title}"
    }
  ]
}
    response = requests.post(url, headers=headers, data=json.dumps(data))

    return response.json()


for i in titles:
    operation = generate_text(i)
    operations_ids.append((i, operation['id']))

# %%
generated = []
for operation in operations_ids[::]:
    response = requests.get(f"https://llm.api.cloud.yandex.net/operations/{operation[1]}", headers={"Authorization": f"Bearer {token}"})
    answ = response.json()
    try:
        generated.append((operation[0], answ['response']['alternatives'][0]['message']['text']))
        operations_ids.remove(operation)
    except:
        print(answ)
        pass

# %%
tmp = pd.DataFrame(generated, columns=['title','generated_text'])
generated_result = pd.concat([generated_result, tmp])
generated_result=generated_result.drop_duplicates().reset_index(drop=True)

# %%
generated_result
# Out:
#                                                   title  \
# 0     Автора пособия «Как убить своего мужа» обвинил...
# 1     На Avito нашли пропавшие кованые ворота с дачи...
# 2                  Sharp представила самый четкий экран
# 3         Большие панды перестали быть вымирающим видом
# 4     «Мистер Трололо» ворвался в эфир американского...
# ...                                                 ...
# 2424  Одноклубника Нурмагомедова нокаутировали в деб...
# 2425  Китаянка захотела вина со змеиным ядом и впала...
# 2426  Журналист «Ленты.ру» назван лучшим молодым кин...
# 2427  Обновление Windows 10 убило устройства пользов...
# 2428  Странный зверь с калифорнийской помойки оказал...
#
#                                          generated_text
# 0     ### Автора пособия «Как убить своего мужа» обв...
# 1     ### На Avito нашли пропавшие кованые ворота с ...
# 2     **Sharp представила самый чёткий экран: прорыв...
# 3     **Большие панды перестали быть вымирающим видо...
# 4     #### «Мистер Трололо» ворвался в эфир американ...
# ...                                                 ...
# 2424  #### Одноклубник Хабиба Нурмагомедова нокаутир...
# 2425  **Китаянка захотела вина со змеиным ядом и впа...
# 2426  ### Журналист «Ленты.ру» признан лучшим молоды...
# 2427  ### Обновление Windows 10 вызвало проблемы у п...
# 2428  **Странный зверь с калифорнийской помойки оказ...
#
# [2429 rows x 2 columns]

# %%
with open("operations_ids_pro.txt", "w", encoding="utf-8") as file:
    for item in operations_ids:
        file.write(f"{item}\n")

# %%
generated_result.to_csv('generated_YaGPT_lite3_.csv')
